# %%
import os

import numpy as np
import cv2
import matplotlib.pyplot as plt

from scipy import signal

from droplets import do_cutouts
from droplets import do_metrics
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

import gc

# %%
#import droplets as drop
# dir(drop)

# %% [markdown]
# ### DIRECTORY LOOP BELOW

# %%
directories_with_inputs = ['/Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um','/Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole']

dir_for_results = '/Volumes/LaCie Drive/Lab/Results/200506/'

#directory_with_input.split(sep='/')[-1]

# %%
cuts = []
metrics = []
fig = None
cut = None

for directory_with_input_index, directory_with_input in enumerate(directories_with_inputs):
    path_to_files = directory_with_input
    path_to_results = '/'.join([dir_for_results,
                                'Cuts/' + directory_with_input.split(sep='/')[-1]])
    os.makedirs(path_to_results, exist_ok=True)

    path_to_diagnostics = '/'.join([dir_for_results,
                                    'Diagnostics/' + directory_with_input.split(sep='/')[-1]])
    os.makedirs(path_to_diagnostics, exist_ok=True)

    list_of_files = [my_file for my_file in os.listdir(
        path_to_files) if not my_file.startswith('.')]  # to avoid hidden files like .DS_file
    print(directory_with_input+':')
    print('found {0} files'.format(str(len(list_of_files))))
    list_of_files.sort()
    print('sorted')

    list_of_files_to_do = list_of_files.copy()[1400:]

    metrics_list = [None]*len(list_of_files_to_do)
    index_list = [None]*len(list_of_files_to_do)
    
    if True:  # Do all

        for file_index, file_name in enumerate(list_of_files_to_do):
            full_path = os.path.join(path_to_files, file_name)
            #image = cv2.imread(full_path)

            print(full_path)

            #temp_file = ImageFile(path_to_files, file_name)
            # metric,cut=GD_metric(image,d_um=2.2)
            show_diagnostics = True
            cuts, metrics, fig = do_cutouts(full_path, d_um=2.2, smallest_size_um2=10000,
                                            closing_kernel=30, threshold_fraction=0.15, show_diagnostics=show_diagnostics)

            # Make this True if you want to see the cuts
            if False:
                for cut_index, cut in enumerate(cuts):
                    plt.figure()
                    plt.imshow(cut, cmap='gray', vmin=0, vmax=255)
                    # plt.colorbar()
                    plt.title('{0:.0f}'.format(metrics[cut_index]))

            if True:
                for cut_index, cut in enumerate(cuts):
                    cv2.imwrite('{0}/metric_{1:.0f}_cut{2}_{3}'.format(path_to_results,
                                                                       metrics[cut_index], cut_index, file_name), cut)

            if show_diagnostics:
                fig.savefig(
                    '{0}/diag_{1}'.format(path_to_diagnostics, file_name), format='png')

            plt.close('all')

    if False:  # Only metrics

        for file_index, file_name in enumerate(list_of_files_to_do):
            full_path = os.path.join(path_to_files, file_name)
            #image = cv2.imread(full_path)

            print(full_path)

            #temp_file = ImageFile(path_to_files, file_name)
            # metric,cut=GD_metric(image,d_um=2.2)
            metrics = do_metrics(full_path, d_um=2.2, smallest_size_um2=10000,
                                 closing_kernel=30, threshold_fraction=0.15)
            metrics_list[file_index] = metrics
            index_list[file_index] = file_index

            plt.close('all')
        np.save('{0}/metrics_list_0-100'.format(path_to_diagnostics,
                                          file_name), metrics_list)
        np.save('{0}/index_list_first0-100'.format(path_to_diagnostics, file_name), index_list)

        #print('{0:.3f}\t {1}'.format(metric,file_name))
# Out:
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um:
# found 2900 files
# sorted
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172733-0.png
# Collecting 0 ...
# Unreachable objects: 58574
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172734-1.png
# Collecting 0 ...
# Unreachable objects: 23516
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172734-2.png
# Collecting 0 ...
# Unreachable objects: 23517
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172734-3.png
# Collecting 0 ...
# Unreachable objects: 23515
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172734-4.png
# Collecting 0 ...
# Unreachable objects: 23513
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172735-5.png
# Collecting 0 ...
# Unreachable objects: 23513
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172735-6.png
# Collecting 0 ...
# Unreachable objects: 23513
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172735-7.png
# Collecting 0 ...
# Unreachable objects: 23514
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172735-8.png
# Collecting 0 ...
# Unreachable objects: 23516
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172736-10.png
# Collecting 0 ...
# Unreachable objects: 23531
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172736-11.png
# Collecting 0 ...
# Unreachable objects: 23516
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172736-12.png
# Collecting 0 ...
# Unreachable objects: 23519
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172736-9.png
# Collecting 0 ...
# Unreachable objects: 23530
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172737-13.png
# Collecting 0 ...
# Unreachable objects: 23514
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172737-14.png
# Collecting 0 ...
# Unreachable objects: 23516
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172737-15.png
# Collecting 0 ...
# Unreachable objects: 23516
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172737-16.png
# Collecting 0 ...
# Unreachable objects: 23516
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172738-17.png
# Collecting 0 ...
# Unreachable objects: 23515
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172738-18.png
# Collecting 0 ...
# Unreachable objects: 23516
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172738-19.png
# Collecting 0 ...
# Unreachable objects: 23531
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172739-20.png
# Collecting 0 ...
# Unreachable objects: 23530
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172739-21.png
# Collecting 0 ...
# Unreachable objects: 23515
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172739-22.png
# Collecting 0 ...
# Unreachable objects: 23513
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172739-23.png
# Collecting 0 ...
# Unreachable objects: 23513
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172740-24.png
# Collecting 0 ...
# Unreachable objects: 23514
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172740-25.png
# Collecting 0 ...
# Unreachable objects: 23515
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172740-26.png
# Collecting 0 ...
# Unreachable objects: 23515
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172740-27.png
# Collecting 0 ...
# Unreachable objects: 23513
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172741-28.png
# Collecting 0 ...
# Unreachable objects: 23518
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172741-29.png
# Collecting 0 ...
# Unreachable objects: 23531
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172741-30.png
# Collecting 0 ...
# Unreachable objects: 23515
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172741-31.png
# Collecting 0 ...
# Unreachable objects: 23516
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172742-32.png
# Collecting 0 ...
# Unreachable objects: 23531
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172743-33.png
# Collecting 0 ...
# Unreachable objects: 23531
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172743-34.png
# Collecting 0 ...
# Unreachable objects: 23529
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172743-35.png
# Collecting 0 ...
# Unreachable objects: 23517
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172744-36.png
# Collecting 0 ...
# Unreachable objects: 23514
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172744-37.png
# Collecting 0 ...
# Unreachable objects: 23517
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172744-38.png
# Collecting 0 ...
# Unreachable objects: 23514
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172745-39.png
# Collecting 0 ...
# Unreachable objects: 23515
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172745-40.png
# Collecting 0 ...
# Unreachable objects: 23517
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172745-41.png
# Collecting 0 ...
# Unreachable objects: 23517
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172745-42.png
# Collecting 0 ...
# Unreachable objects: 23519
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172746-43.png
# Collecting 0 ...
# Unreachable objects: 23518
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172746-44.png
# Collecting 0 ...
# Unreachable objects: 23517
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172746-45.png
# Collecting 0 ...
# Unreachable objects: 23517
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172746-46.png
# Collecting 0 ...
# Unreachable objects: 23515
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172747-47.png
# Collecting 0 ...
# Unreachable objects: 23531
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172747-48.png
# Collecting 0 ...
# Unreachable objects: 23516
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172747-49.png
# Collecting 0 ...
# Unreachable objects: 23516
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172747-50.png
# Collecting 0 ...
# Unreachable objects: 23533
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172748-51.png
# Collecting 0 ...
# Unreachable objects: 23515
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172748-52.png
# Collecting 0 ...
# Unreachable objects: 23515
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172748-53.png
# Collecting 0 ...
# Unreachable objects: 23515
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172749-54.png
# Collecting 0 ...
# Unreachable objects: 23518
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172749-55.png
# Collecting 0 ...
# Unreachable objects: 23516
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172749-56.png
# Collecting 0 ...
# Unreachable objects: 23518
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172749-57.png
# Collecting 0 ...
# Unreachable objects: 23498
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172750-58.png
# Collecting 0 ...
# Unreachable objects: 23518
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172750-59.png
# Collecting 0 ...
# Unreachable objects: 23515
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172750-60.png
# Collecting 0 ...
# Unreachable objects: 23535
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172751-61.png
# Collecting 0 ...
# Unreachable objects: 23519
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172751-62.png
# Collecting 0 ...
# Unreachable objects: 23517
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172752-63.png
# Collecting 0 ...
# Unreachable objects: 23516
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172753-64.png
# Collecting 0 ...
# Unreachable objects: 23519
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172753-65.png
# Collecting 0 ...
# Unreachable objects: 23519
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172753-66.png
# Collecting 0 ...
# Unreachable objects: 23517
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172753-67.png
# Collecting 0 ...
# Unreachable objects: 23517
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172754-68.png
# Collecting 0 ...
# Unreachable objects: 23515
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172754-69.png
# Collecting 0 ...
# Unreachable objects: 23515
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172754-70.png
# Collecting 0 ...
# Unreachable objects: 23516
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172754-71.png
# Collecting 0 ...
# Unreachable objects: 23514
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172755-72.png
# Collecting 0 ...
# Unreachable objects: 23515
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172755-73.png
# Collecting 0 ...
# Unreachable objects: 23515
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172755-74.png
# Collecting 0 ...
# Unreachable objects: 23515
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172755-75.png
# Collecting 0 ...
# Unreachable objects: 23516
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172756-76.png
# Collecting 0 ...
# Unreachable objects: 23515
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172756-77.png
# Collecting 0 ...
# Unreachable objects: 23515
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172756-78.png
# Collecting 0 ...
# Unreachable objects: 23516
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172757-79.png
# Collecting 0 ...
# Unreachable objects: 23531
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172757-80.png
# Collecting 0 ...
# Unreachable objects: 23516
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172758-81.png
# Collecting 0 ...
# Unreachable objects: 23514
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172758-82.png
# Collecting 0 ...
# Unreachable objects: 23513
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172758-83.png
# Collecting 0 ...
# Unreachable objects: 23515
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172758-84.png
# Collecting 0 ...
# Unreachable objects: 23518
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172759-85.png
# Collecting 0 ...
# Unreachable objects: 23515
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172759-86.png
# Collecting 0 ...
# Unreachable objects: 23518
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172800-87.png
# Collecting 0 ...
# Unreachable objects: 23516
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172801-88.png
# Collecting 0 ...
# Unreachable objects: 23517
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172801-89.png
# Collecting 0 ...
# Unreachable objects: 23518
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172801-90.png
# Collecting 0 ...
# Unreachable objects: 23515
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172801-91.png
# Collecting 0 ...
# Unreachable objects: 23518
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172802-92.png
# Collecting 0 ...
# Unreachable objects: 23517
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172802-93.png
# Collecting 0 ...
# Unreachable objects: 23517
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172802-94.png
# Collecting 0 ...
# Unreachable objects: 23514
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172802-95.png
# Collecting 0 ...
# Unreachable objects: 23501
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172803-96.png
# Collecting 0 ...
# Unreachable objects: 23516
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172803-97.png
# Collecting 0 ...
# Unreachable objects: 23516
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172803-98.png
# Collecting 0 ...
# Unreachable objects: 23517
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.94mm-05062020172803-99.png
# Collecting 0 ...
# Unreachable objects: 23516
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172901-0.png
# Collecting 0 ...
# Unreachable objects: 23527
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172901-1.png
# Collecting 0 ...
# Unreachable objects: 23508
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172901-2.png
# Collecting 0 ...
# Unreachable objects: 23508
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172901-3.png
# Collecting 0 ...
# Unreachable objects: 23509
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172902-4.png
# Collecting 0 ...
# Unreachable objects: 23506
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172902-5.png
# Collecting 0 ...
# Unreachable objects: 23508
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172902-6.png
# Collecting 0 ...
# Unreachable objects: 23506
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172903-10.png
# Collecting 0 ...
# Unreachable objects: 23505
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172903-7.png
# Collecting 0 ...
# Unreachable objects: 23509
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172903-8.png
# Collecting 0 ...
# Unreachable objects: 23505
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172903-9.png
# Collecting 0 ...
# Unreachable objects: 23506
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172904-11.png
# Collecting 0 ...
# Unreachable objects: 23510
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172904-12.png
# Collecting 0 ...
# Unreachable objects: 23510
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172904-13.png
# Collecting 0 ...
# Unreachable objects: 23512
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172904-14.png
# Collecting 0 ...
# Unreachable objects: 23552
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172905-15.png
# Collecting 0 ...
# Unreachable objects: 23509
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172905-16.png
# Collecting 0 ...
# Unreachable objects: 23533
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172905-17.png
# Collecting 0 ...
# Unreachable objects: 23510
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172905-18.png
# Collecting 0 ...
# Unreachable objects: 23509
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172906-19.png
# Collecting 0 ...
# Unreachable objects: 23509
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172906-20.png
# Collecting 0 ...
# Unreachable objects: 23492
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172906-21.png
# Collecting 0 ...
# Unreachable objects: 23551
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172906-22.png
# Collecting 0 ...
# Unreachable objects: 23505
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172907-23.png
# Collecting 0 ...
# Unreachable objects: 23504
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172907-24.png
# Collecting 0 ...
# Unreachable objects: 23503
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172907-25.png
# Collecting 0 ...
# Unreachable objects: 23504
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172907-26.png
# Collecting 0 ...
# Unreachable objects: 23505
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172907-27.png
# Collecting 0 ...
# Unreachable objects: 23504
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172908-28.png
# Collecting 0 ...
# Unreachable objects: 23506
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172908-29.png
# Collecting 0 ...
# Unreachable objects: 23508
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172908-30.png
# Collecting 0 ...
# Unreachable objects: 23508
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172909-31.png
# Collecting 0 ...
# Unreachable objects: 23508
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172909-32.png
# Collecting 0 ...
# Unreachable objects: 23509
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172909-33.png
# Collecting 0 ...
# Unreachable objects: 23508
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172910-34.png
# Collecting 0 ...
# Unreachable objects: 23510
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172910-35.png
# Collecting 0 ...
# Unreachable objects: 23510
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172910-36.png
# Collecting 0 ...
# Unreachable objects: 23511
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172910-37.png
# Collecting 0 ...
# Unreachable objects: 23508
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172911-38.png
# Collecting 0 ...
# Unreachable objects: 23508
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172911-39.png
# Collecting 0 ...
# Unreachable objects: 23507
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172911-40.png
# Collecting 0 ...
# Unreachable objects: 23506
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172912-41.png
# Collecting 0 ...
# Unreachable objects: 23505
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172912-42.png
# Collecting 0 ...
# Unreachable objects: 23505
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172912-43.png
# Collecting 0 ...
# Unreachable objects: 23504
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172912-44.png
# Collecting 0 ...
# Unreachable objects: 23506
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172913-45.png
# Collecting 0 ...
# Unreachable objects: 23507
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172913-46.png
# Collecting 0 ...
# Unreachable objects: 23507
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172913-47.png
# Collecting 0 ...
# Unreachable objects: 23504
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172913-48.png
# Collecting 0 ...
# Unreachable objects: 23519
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172914-49.png
# Collecting 0 ...
# Unreachable objects: 23505
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172914-50.png
# Collecting 0 ...
# Unreachable objects: 23508
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172914-51.png
# Collecting 0 ...
# Unreachable objects: 23511
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172914-52.png
# Collecting 0 ...
# Unreachable objects: 23507
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172915-53.png
# Collecting 0 ...
# Unreachable objects: 23508
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172915-54.png
# Collecting 0 ...
# Unreachable objects: 23508
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172915-55.png
# Collecting 0 ...
# Unreachable objects: 23508
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172915-56.png
# Collecting 0 ...
# Unreachable objects: 23510
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172916-57.png
# Collecting 0 ...
# Unreachable objects: 23508
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172916-58.png
# Collecting 0 ...
# Unreachable objects: 23509
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172916-59.png
# Collecting 0 ...
# Unreachable objects: 23508
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172916-60.png
# Collecting 0 ...
# Unreachable objects: 23509
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172917-61.png
# Collecting 0 ...
# Unreachable objects: 23506
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172917-62.png
# Collecting 0 ...
# Unreachable objects: 23505
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172917-63.png
# Collecting 0 ...
# Unreachable objects: 23508
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172917-64.png
# Collecting 0 ...
# Unreachable objects: 23505
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172918-65.png
# Collecting 0 ...
# Unreachable objects: 23504
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172918-66.png
# Collecting 0 ...
# Unreachable objects: 23506
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172918-67.png
# Collecting 0 ...
# Unreachable objects: 23505
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172918-68.png
# Collecting 0 ...
# Unreachable objects: 23505
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172919-69.png
# Collecting 0 ...
# Unreachable objects: 23506
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172919-70.png
# Collecting 0 ...
# Unreachable objects: 23510
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172919-71.png
# Collecting 0 ...
# Unreachable objects: 23507
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172920-72.png
# Collecting 0 ...
# Unreachable objects: 23508
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172920-73.png
# Collecting 0 ...
# Unreachable objects: 23507
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172920-74.png
# Collecting 0 ...
# Unreachable objects: 23505
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172920-75.png
# Collecting 0 ...
# Unreachable objects: 23504
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172921-76.png
# Collecting 0 ...
# Unreachable objects: 23503
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172921-77.png
# Collecting 0 ...
# Unreachable objects: 23504
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172921-78.png
# Collecting 0 ...
# Unreachable objects: 23504
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172921-79.png
# Collecting 0 ...
# Unreachable objects: 23507
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172922-80.png
# Collecting 0 ...
# Unreachable objects: 23504
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172922-81.png
# Collecting 0 ...
# Unreachable objects: 23507
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172922-82.png
# Collecting 0 ...
# Unreachable objects: 23511
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172922-83.png
# Collecting 0 ...
# Unreachable objects: 23509
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172923-84.png
# Collecting 0 ...
# Unreachable objects: 23509
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172923-85.png
# Collecting 0 ...
# Unreachable objects: 23508
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172923-86.png
# Collecting 0 ...
# Unreachable objects: 23508
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172923-87.png
# Collecting 0 ...
# Unreachable objects: 23512
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172924-88.png
# Collecting 0 ...
# Unreachable objects: 23508
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172924-89.png
# Collecting 0 ...
# Unreachable objects: 23508
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172924-90.png
# Collecting 0 ...
# Unreachable objects: 23511
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172925-91.png
# Collecting 0 ...
# Unreachable objects: 23510
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172925-92.png
# Collecting 0 ...
# Unreachable objects: 23528
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172925-93.png
# Collecting 0 ...
# Unreachable objects: 23509
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172925-94.png
# Collecting 0 ...
# Unreachable objects: 23508
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172926-95.png
# Collecting 0 ...
# Unreachable objects: 23511
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Diffusor_300um/40_gain_minus2.95mm-05062020172926-96.png
# Collecting 0 ...
# Unreachable objects: 23508
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# ...
# Collecting 0 ...
# Unreachable objects: 23474
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163406-59.png
# Collecting 0 ...
# Unreachable objects: 23532
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163407-60.png
# Collecting 0 ...
# Unreachable objects: 23535
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163407-61.png
# Collecting 0 ...
# Unreachable objects: 23488
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163407-62.png
# Collecting 0 ...
# Unreachable objects: 23475
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163407-63.png
# Collecting 0 ...
# Unreachable objects: 23489
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163408-64.png
# Collecting 0 ...
# Unreachable objects: 23490
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163408-65.png
# Collecting 0 ...
# Unreachable objects: 23476
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163408-66.png
# Collecting 0 ...
# Unreachable objects: 23506
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163408-67.png
# Collecting 0 ...
# Unreachable objects: 23507
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163409-68.png
# Collecting 0 ...
# Unreachable objects: 23504
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163409-69.png
# Collecting 0 ...
# Unreachable objects: 23505
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163409-70.png
# Collecting 0 ...
# Unreachable objects: 23475
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163409-71.png
# Collecting 0 ...
# Unreachable objects: 23491
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163410-72.png
# Collecting 0 ...
# Unreachable objects: 23508
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163410-73.png
# Collecting 0 ...
# Unreachable objects: 23508
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163410-74.png
# Collecting 0 ...
# Unreachable objects: 23477
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163411-75.png
# Collecting 0 ...
# Unreachable objects: 23491
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163411-76.png
# Collecting 0 ...
# Unreachable objects: 23491
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163411-77.png
# Collecting 0 ...
# Unreachable objects: 23536
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163411-78.png
# Collecting 0 ...
# Unreachable objects: 23489
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163412-79.png
# Collecting 0 ...
# Unreachable objects: 23504
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163412-80.png
# Collecting 0 ...
# Unreachable objects: 23490
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163412-81.png
# Collecting 0 ...
# Unreachable objects: 23520
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163412-82.png
# Collecting 0 ...
# Unreachable objects: 23507
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163413-83.png
# Collecting 0 ...
# Unreachable objects: 23490
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163413-84.png
# Collecting 0 ...
# Unreachable objects: 23490
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163413-85.png
# Collecting 0 ...
# Unreachable objects: 23489
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163413-86.png
# Collecting 0 ...
# Unreachable objects: 23478
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163414-87.png
# Collecting 0 ...
# Unreachable objects: 23491
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163414-88.png
# Collecting 0 ...
# Unreachable objects: 23488
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163414-89.png
# Collecting 0 ...
# Unreachable objects: 23474
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163414-90.png
# Collecting 0 ...
# Unreachable objects: 23491
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163415-91.png
# Collecting 0 ...
# Unreachable objects: 23533
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163415-92.png
# Collecting 0 ...
# Unreachable objects: 23533
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163415-93.png
# Collecting 0 ...
# Unreachable objects: 23475
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163415-94.png
# Collecting 0 ...
# Unreachable objects: 23491
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163416-95.png
# Collecting 0 ...
# Unreachable objects: 23479
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163416-96.png
# Collecting 0 ...
# Unreachable objects: 23477
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163416-97.png
# Collecting 0 ...
# Unreachable objects: 23478
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163416-98.png
# Collecting 0 ...
# Unreachable objects: 23492
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.96mm-05062020163417-99.png
# Collecting 0 ...
# Unreachable objects: 23477
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.97mm-05062020163506-0.png
# Collecting 0 ...
# Unreachable objects: 23532
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.97mm-05062020163506-1.png
# Collecting 0 ...
# Unreachable objects: 23562
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.97mm-05062020163507-2.png
# Collecting 0 ...
# Unreachable objects: 23561
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.97mm-05062020163507-3.png
# Collecting 0 ...
# Unreachable objects: 23472
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.97mm-05062020163507-4.png
# Collecting 0 ...
# Unreachable objects: 23563
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.97mm-05062020163507-5.png
# Collecting 0 ...
# Unreachable objects: 23470
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.97mm-05062020163508-6.png
# Collecting 0 ...
# Unreachable objects: 23530
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.97mm-05062020163508-7.png
# Collecting 0 ...
# Unreachable objects: 23562
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.97mm-05062020163508-8.png
# Collecting 0 ...
# Unreachable objects: 23471
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.97mm-05062020163508-9.png
# Collecting 0 ...
# Unreachable objects: 23546
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.97mm-05062020163509-10.png
# Collecting 0 ...
# Unreachable objects: 23471
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.97mm-05062020163509-11.png
# Collecting 0 ...
# Unreachable objects: 23533
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.97mm-05062020163509-12.png
# Collecting 0 ...
# Unreachable objects: 23592
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.97mm-05062020163510-13.png
# Collecting 0 ...
# Unreachable objects: 23564
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.97mm-05062020163510-14.png
# Collecting 0 ...
# Unreachable objects: 23562
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.97mm-05062020163510-15.png
# Collecting 0 ...
# Unreachable objects: 23549
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.97mm-05062020163510-16.png
# Collecting 0 ...
# Unreachable objects: 23564
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.97mm-05062020163511-17.png
# Collecting 0 ...
# Unreachable objects: 23592
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.97mm-05062020163511-18.png
# Collecting 0 ...
# Unreachable objects: 23532
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.97mm-05062020163511-19.png
# Collecting 0 ...
# Unreachable objects: 23578
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.97mm-05062020163511-20.png
# Collecting 0 ...
# Unreachable objects: 23562
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.97mm-05062020163512-21.png
# Collecting 0 ...
# Unreachable objects: 23532
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.97mm-05062020163512-22.png
# Collecting 0 ...
# Unreachable objects: 23529
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.97mm-05062020163512-23.png
# Collecting 0 ...
# Unreachable objects: 23561
# Remaining Garbage:
# []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage:
# []
#
# /Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200506/Scans/Medium_hole/47_9_gain_minus2.97mm-05062020163513-24.png

# %% [markdown]
# ### WIDGET BELOW

# %%
import sys


def get_size(obj, seen=None):
    """Recursively finds size of objects in bytes"""
    size = sys.getsizeof(obj)
    if seen is None:
        seen = set()
    obj_id = id(obj)
    if obj_id in seen:
        return 0
    # Important mark as seen *before* entering recursion to gracefully handle
    # self-referential objects
    seen.add(obj_id)
    if hasattr(obj, '__dict__'):
        for cls in obj.__class__.__mro__:
            if '__dict__' in cls.__dict__:
                d = cls.__dict__['__dict__']
                if inspect.isgetsetdescriptor(d) or inspect.ismemberdescriptor(d):
                    size += get_size(obj.__dict__, seen)
                break
    if isinstance(obj, dict):
        size += sum((get_size(v, seen) for v in obj.values()))
        size += sum((get_size(k, seen) for k in obj.keys()))
    elif hasattr(obj, '__iter__') and not isinstance(obj, (str, bytes, bytearray)):
        size += sum((get_size(i, seen) for i in obj))

    if hasattr(obj, '__slots__'):  # can have __slots__ with __dict__
        size += sum(get_size(getattr(obj, s), seen)
                    for s in obj.__slots__ if hasattr(obj, s))

    return size


for index, thing in enumerate(locals().items()):
    print(get_size(thing[1]))

# %%
# globals().values()
import pprint

for i in range(2):
    print('Collecting %d ...' % i)
    n = gc.collect()
    print('Unreachable objects:', n)
    print('Remaining Garbage:', )
    pprint.pprint(gc.garbage)
    print()

# %%
huge = np.random.random([1000, 1000])

# %%
gc.collect()
# Out:
# 50

# %%
import sys


def sizeof_fmt(num, suffix='B'):
    ''' by Fred Cirera,  https://stackoverflow.com/a/1094933/1870254, modified'''
    for unit in ['', 'Ki', 'Mi', 'Gi', 'Ti', 'Pi', 'Ei', 'Zi']:
        if abs(num) < 1024.0:
            return "%3.1f %s%s" % (num, unit, suffix)
        num /= 1024.0
    return "%.1f %s%s" % (num, 'Yi', suffix)


for name, size in sorted(((name, sys.getsizeof(value)) for name, value in globals().items()),
                         key=lambda x: -x[1])[:10]:
    print("{:>30}: {:>8}".format(name, sizeof_fmt(size)))
# Out:
#                  list_of_files: 16.2 KiB
#            list_of_files_to_do: 15.7 KiB
#                           _i12:  2.1 KiB
#                           _i13:  2.1 KiB
#                            _i4:  2.1 KiB
#                            _i5:  2.1 KiB
#                    interactive:  1.0 KiB
#                          fixed:  1.0 KiB
#                            _ii:  588.0 B
#                           _i25:  588.0 B

# %%
np.shape(cuts[1])

# %%
# path to file to run widget on
file_path = '/Users/olofjonsson/Projects/Ice/Droplet_codes/Package/Example_images/255kHz_48ulpermin-06012020122750-15.png'

# %%
def test_params(path_to_image,
                threshold_fraction=0.15,
                closing_kernel=30,
                smallest_size_um2=10000,
                d_um=2.2,
                scaling=0.345):
    cuts, metrics, fig = do_cutouts(path_to_image=path_to_image, d_um=d_um, closing_kernel=closing_kernel,
                                    threshold_fraction=threshold_fraction, scaling=scaling, show_diagnostics=True)
    fig.show()


_ = interact(test_params, path_to_image=fixed(file_path),
             d_um=widgets.FloatSlider(min=0.1, max=100, value=2.2),
             closing_kernel=widgets.IntSlider(min=1, max=100, value=30),
             smallest_size_um2=widgets.FloatSlider(
                 min=1, max=1e6, value=10000),
             threshold_fraction=widgets.FloatSlider(
                 min=0.01, max=1, value=0.15),
             scaling=fixed(0.345))

# %%
diffusor_metrics = np.load(
    '/Volumes/LaCie Drive/Lab/Results/200922/Diagnostics/Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200602/Diffusor_30_40mm_gain40/metrics_list.npy', allow_pickle=True)
pinhole_metrics = np.load(
    '/Volumes/LaCie Drive/Lab/Results/200922/Diagnostics/Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200602/Medium_30_40_gain47.9/metrics_list.npy', allow_pickle=True)
normal_metrics = np.load(
    '/Volumes/LaCie Drive/Lab/Results/200922/Diagnostics/Volumes/LaCie Drive/Lab/Raw_data/Home_lab/200602/Normal_30_40/metrics_list.npy', allow_pickle=True)

# %%
n=plt.hist([np.concatenate(diffusor_metrics).ravel(), np.concatenate(pinhole_metrics).ravel(
), np.concatenate(normal_metrics).ravel()], 
           label=['diffusor', 'pinhole', 'normal'],  
           cumulative=False,
           stacked=False,
           log=False,
           density=False,
           bins='stone',
           alpha=0.8)
# Out:
# /Users/olofjonsson/.virtualenvs/opython/lib/python3.8/site-packages/numpy/lib/histograms.py:671: RuntimeWarning: The number of bins estimated may be suboptimal.
#   bin_edges, _ = _get_bin_edges(a, bins, range, weights)

# %%
plt.plot(n[1],n[0][0])
plt.plot(n[0][2],n[0][1])
plt.plot(n[0][2],n[0][2])
# Out:
# --------------------------------------------------------------------
# ValueError                         Traceback (most recent call last)
# <ipython-input-9-bc48143dea1f> in <module>
# ----> 1 plt.plot(n[1],n[0][0])
#       2 plt.plot(n[0][2],n[0][1])
#       3 plt.plot(n[0][2],n[0][2])
#
# ~/.virtualenvs/opython/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/.virtualenvs/opython/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ~/.virtualenvs/opython/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# ~/.virtualenvs/opython/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (131,) and (130,)

# %%
n[0]
# Out:
# array([[5.100e+01, 6.100e+01, 7.200e+01, 8.000e+01, 7.800e+01, 9.400e+01,
#         1.040e+02, 1.020e+02, 1.100e+02, 1.280e+02, 1.250e+02, 1.010e+02,
#         1.090e+02, 9.000e+01, 1.080e+02, 1.170e+02, 9.700e+01, 9.700e+01,
#         1.010e+02, 9.700e+01, 1.080e+02, 7.900e+01, 1.010e+02, 9.300e+01,
#         9.900e+01, 9.700e+01, 1.030e+02, 8.500e+01, 6.800e+01, 1.030e+02,
#         7.300e+01, 8.900e+01, 7.400e+01, 7.600e+01, 8.300e+01, 8.400e+01,
#         6.300e+01, 7.300e+01, 5.700e+01, 6.900e+01, 5.200e+01, 4.200e+01,
#         4.600e+01, 4.800e+01, 4.200e+01, 4.700e+01, 4.000e+01, 4.100e+01,
#         3.800e+01, 3.600e+01, 3.900e+01, 4.400e+01, 3.800e+01, 3.600e+01,
#         3.500e+01, 4.500e+01, 4.900e+01, 2.600e+01, 3.800e+01, 4.000e+01,
#         4.300e+01, 4.500e+01, 4.100e+01, 4.900e+01, 4.000e+01, 5.500e+01,
#         4.900e+01, 5.400e+01, 4.400e+01, 4.100e+01, 5.000e+01, 4.200e+01,
#         5.700e+01, 4.800e+01, 5.000e+01, 4.700e+01, 3.400e+01, 3.700e+01,
#         3.300e+01, 2.900e+01, 2.300e+01, 2.800e+01, 2.000e+01, 1.400e+01,
#         1.100e+01, 1.000e+01, 1.100e+01, 6.000e+00, 6.000e+00, 4.000e+00,
#         4.000e+00, 1.000e+00, 5.000e+00, 6.000e+00, 2.000e+00, 2.000e+00,
#         0.000e+00, 2.000e+00, 1.000e+00, 1.000e+00, 2.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 1.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 3.000e+00, 2.000e+00, 0.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 1.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00],
#        [1.150e+02, 9.380e+02, 1.358e+03, 1.305e+03, 9.600e+02, 7.610e+02,
#         6.430e+02, 5.710e+02, 4.480e+02, 3.110e+02, 1.970e+02, 1.430e+02,
#         1.020e+02, 7.700e+01, 4.600e+01, 4.900e+01, 4.100e+01, 3.600e+01,
#         3.300e+01, 2.500e+01, 2.600e+01, 2.800e+01, 2.400e+01, 3.100e+01,
#         2.000e+01, 2.100e+01, 2.500e+01, 3.000e+01, 2.000e+01, 1.400e+01,
#         1.500e+01, 1.200e+01, 1.400e+01, 1.200e+01, 7.000e+00, 9.000e+00,
#         1.200e+01, 1.000e+01, 7.000e+00, 2.000e+00, 3.000e+00, 2.000e+00,
#         2.000e+00, 0.000e+00, 1.000e+00, 2.000e+00, 0.000e+00, 2.000e+00,
#         0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#        [1.341e+03, 3.480e+02, 2.100e+02, 1.070e+02, 1.100e+02, 7.000e+01,
#         7.000e+01, 5.400e+01, 4.900e+01, 3.900e+01, 3.400e+01, 2.800e+01,
#         3.000e+01, 2.800e+01, 3.000e+01, 2.200e+01, 2.700e+01, 3.000e+01,
#         1.900e+01, 2.300e+01, 2.400e+01, 1.900e+01, 1.800e+01, 2.300e+01,
#         2.000e+01, 1.800e+01, 2.600e+01, 2.300e+01, 2.400e+01, 2.400e+01,
#         2.000e+01, 3.000e+01, 2.200e+01, 2.400e+01, 2.700e+01, 1.500e+01,
#         1.400e+01, 1.300e+01, 1.000e+01, 7.000e+00, 5.000e+00, 9.000e+00,
#         4.000e+00, 3.000e+00, 2.000e+00, 3.000e+00, 1.000e+00, 1.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00]])

# %%
n[1]
# Out:
# array([  2494.41827737,   7517.35246481,  12540.28665225,  17563.22083969,
#         22586.15502713,  27609.08921458,  32632.02340202,  37654.95758946,
#         42677.8917769 ,  47700.82596434,  52723.76015178,  57746.69433923,
#         62769.62852667,  67792.56271411,  72815.49690155,  77838.43108899,
#         82861.36527643,  87884.29946388,  92907.23365132,  97930.16783876,
#        102953.1020262 , 107976.03621364, 112998.97040108, 118021.90458853,
#        123044.83877597, 128067.77296341, 133090.70715085, 138113.64133829,
#        143136.57552573, 148159.50971318, 153182.44390062, 158205.37808806,
#        163228.3122755 , 168251.24646294, 173274.18065038, 178297.11483783,
#        183320.04902527, 188342.98321271, 193365.91740015, 198388.85158759,
#        203411.78577503, 208434.71996248, 213457.65414992, 218480.58833736,
#        223503.5225248 , 228526.45671224, 233549.39089969, 238572.32508713,
#        243595.25927457, 248618.19346201, 253641.12764945, 258664.06183689,
#        263686.99602434, 268709.93021178, 273732.86439922, 278755.79858666,
#        283778.7327741 , 288801.66696154, 293824.60114899, 298847.53533643,
#        303870.46952387, 308893.40371131, 313916.33789875, 318939.27208619,
#        323962.20627364, 328985.14046108, 334008.07464852, 339031.00883596,
#        344053.9430234 , 349076.87721084, 354099.81139829, 359122.74558573,
#        364145.67977317, 369168.61396061, 374191.54814805, 379214.48233549,
#        384237.41652294, 389260.35071038, 394283.28489782, 399306.21908526,
#        404329.1532727 , 409352.08746014, 414375.02164759, 419397.95583503,
#        424420.89002247, 429443.82420991, 434466.75839735, 439489.69258479,
#        444512.62677224, 449535.56095968, 454558.49514712, 459581.42933456,
#        464604.363522  , 469627.29770944, 474650.23189689, 479673.16608433,
#        484696.10027177, 489719.03445921, 494741.96864665, 499764.9028341 ,
#        504787.83702154, 509810.77120898, 514833.70539642, 519856.63958386,
#        524879.5737713 , 529902.50795875, 534925.44214619, 539948.37633363,
#        544971.31052107, 549994.24470851, 555017.17889595, 560040.1130834 ,
#        565063.04727084, 570085.98145828, 575108.91564572, 580131.84983316,
#        585154.7840206 , 590177.71820805, 595200.65239549, 600223.58658293,
#        605246.52077037, 610269.45495781, 615292.38914525, 620315.3233327 ,
#        625338.25752014, 630361.19170758, 635384.12589502, 640407.06008246,
#        645429.9942699 , 650452.92845735, 655475.86264479])
